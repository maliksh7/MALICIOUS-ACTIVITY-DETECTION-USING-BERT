# %%
import pandas as pd

# %%
url = "data/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#                                         Flow ID       Source IP   Source Port  \
# 0       192.168.10.5-104.16.207.165-54865-443-6  104.16.207.165           443
# 1         192.168.10.5-104.16.28.216-55054-80-6   104.16.28.216            80
# 2         192.168.10.5-104.16.28.216-55055-80-6   104.16.28.216            80
# 3       192.168.10.16-104.17.241.25-46236-443-6   104.17.241.25           443
# 4       192.168.10.5-104.19.196.102-54863-443-6  104.19.196.102           443
# ...                                         ...             ...           ...
# 225740     192.168.10.15-72.21.91.29-61374-80-6     72.21.91.29            80
# 225741     192.168.10.15-72.21.91.29-61378-80-6     72.21.91.29            80
# 225742     192.168.10.15-72.21.91.29-61375-80-6     72.21.91.29            80
# 225743    192.168.10.15-8.41.222.187-61323-80-6    8.41.222.187            80
# 225744      192.168.10.15-8.43.72.21-61326-80-6      8.43.72.21            80
#
# ...

# %%
df.head()
# Out:
#                                    Flow ID       Source IP   Source Port  \
# 0  192.168.10.5-104.16.207.165-54865-443-6  104.16.207.165           443
# 1    192.168.10.5-104.16.28.216-55054-80-6   104.16.28.216            80
# 2    192.168.10.5-104.16.28.216-55055-80-6   104.16.28.216            80
# 3  192.168.10.16-104.17.241.25-46236-443-6   104.17.241.25           443
# 4  192.168.10.5-104.19.196.102-54863-443-6  104.19.196.102           443
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.5              54865          6  7/7/2017 3:30
# 1    192.168.10.5              55054          6  7/7/2017 3:30
# 2    192.168.10.5              55055          6  7/7/2017 3:30
# 3   192.168.10.16              46236          6  7/7/2017 3:30
# 4    192.168.10.5              54863          6  7/7/2017 3:30
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# 0               3                   2                        0  ...
# ...

# %%
x = range(df[' Label'].size)
y=
# Out:
# range(0, 225745)

# %%
# da.columns

# %%
# da["Source Port"]     # error

# %%
# da.loc[:, ["Source IP", "Source Port", "Destination IP", "Destination Port", "Protocol", "Label"]]

# %%
da.iloc[:, [1,2,3,4,5,84]]          # displaying specific columns by iloc
# Out:
#              Source IP   Source Port  Destination IP   Destination Port  \
# 0       104.16.207.165           443    192.168.10.5              54865
# 1        104.16.28.216            80    192.168.10.5              55054
# 2        104.16.28.216            80    192.168.10.5              55055
# 3        104.17.241.25           443   192.168.10.16              46236
# 4       104.19.196.102           443    192.168.10.5              54863
# ...                ...           ...             ...                ...
# 225740     72.21.91.29            80   192.168.10.15              61374
# 225741     72.21.91.29            80   192.168.10.15              61378
# 225742     72.21.91.29            80   192.168.10.15              61375
# 225743    8.41.222.187            80   192.168.10.15              61323
# 225744      8.43.72.21            80   192.168.10.15              61326
#
#          Protocol   Label
# 0               6  BENIGN
# 1               6  BENIGN
# ...

# %%
df.iloc[:, [1,2,3,4,5,84]].values           # five-tuple labelled
# Out:
# array([['104.16.207.165', 443, '192.168.10.5', 54865, 6, 'BENIGN'],
#        ['104.16.28.216', 80, '192.168.10.5', 55054, 6, 'BENIGN'],
#        ['104.16.28.216', 80, '192.168.10.5', 55055, 6, 'BENIGN'],
#        ...,
#        ['72.21.91.29', 80, '192.168.10.15', 61375, 6, 'BENIGN'],
#        ['8.41.222.187', 80, '192.168.10.15', 61323, 6, 'BENIGN'],
#        ['8.43.72.21', 80, '192.168.10.15', 61326, 6, 'BENIGN']],
#       dtype=object)

# %%
fa = df.iloc[[1,2,3], [1,2,3,4,5,84]]
fa
# Out:
#        Source IP   Source Port  Destination IP   Destination Port   Protocol  \
# 1  104.16.28.216            80    192.168.10.5              55054          6
# 2  104.16.28.216            80    192.168.10.5              55055          6
# 3  104.17.241.25           443   192.168.10.16              46236          6
#
#     Label
# 1  BENIGN
# 2  BENIGN
# 3  BENIGN

# %%
# import matplotlib 
# import matplotlib.pyplot as plt
# %matplotlib inline

# import numpy as np

# %%
# x =  df.columns.get_loc(Label)
# y =  da['BMXWT']
